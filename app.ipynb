# %%
import json
json_file_path = 'static/uploads/parsed.json'
with open(json_file_path, 'r') as file:
        candidates_data = json.load(file)
        
def search_by_skill(skill, dictionary_list):
    results = []
    for dictionary in dictionary_list:
        if "Skills" in dictionary and skill in dictionary["Skills"]:
            results.append(dictionary)
    return results


skill_to_search = "Python"
search_results = search_by_skill(skill_to_search, candidates_data)

for result in search_results:
    print(result)
# Out:
# {'ID': '148', 'Name': 'CURRICULUM', 'Phone Number': ['0092013', '0062008', '9952006'], 'E-Mail': ['aditya.adinasa@gmail.com', 'aditya.adinasa@gmail.com'], 'Qualification': [['CBSE', '1995']], 'Skills': ['Matplotlib', 'Jupyter', 'data analysis', 'consulting', 'analysis', 'analytics', 'Data Analysis', 'SQL', 'Data Analytics', 'research', 'DB2', 'Tableau', 'Banking', 'analyze', 'workflows', 'machine learning', 'Process', 'gmail', 'Seaborn', 'Hive', 'Engineering', 'Design', 'R', 'Big Data', 'Analysis', 'Electronics', 'algorithms', 'Machine learning', 'try', 'MySQL', 'banking', 'Machine Learning', 'Python', 'general ledger', 'Modeling', 'transactions', 'ETL', 'presentations', 'TECHNICAL', 'certification', 'business intelligence', 'Pandas', 'Communication', 'Automation', 'marketing', 'Architecture', 'TECHNICAL SKILLS', 'hypothesis', 'Numpy']}
# ...

# %%
import re

def search_by_skills(conditions, dictionary_list):
    results = []
    for dictionary in dictionary_list:
        if "Skills" in dictionary:
            skills = set(dictionary["Skills"])
            if evaluate_conditions(conditions, skills):
                results.append(dictionary)
    return results

def evaluate_conditions(conditions, skills):
    operator = "&"
    condition_groups = []
    current_group = []
    for condition in conditions:
        if condition == "&":
            operator = "&"
        elif condition == "|":
            operator = "|"
        else:
            current_group.append(condition)
        if operator == "|":
            condition_groups.append(current_group)
            current_group = []
    if current_group:
        condition_groups.append(current_group)

    return any(evaluate_group(group, skills, operator) for group in condition_groups)

def evaluate_group(group, skills, operator):
    if operator == "&":
        return all(re.search(re.escape(condition), " ".join(skills), re.IGNORECASE) for condition in group)
    elif operator == "|":
        return any(re.search(re.escape(condition), " ".join(skills), re.IGNORECASE) for condition in group)
    return False


# Get user input for search conditions
conditions_input = input("Enter search conditions separated by spaces (e.g., Python Java): ")
conditions_list = [condition.strip() for condition in conditions_input.split()]

search_results = search_by_skills(conditions_list, candidates_data)
# Out:
# [{'ID': '148', 'Name': 'CURRICULUM', 'Phone Number': ['0092013', '0062008', '9952006'], 'E-Mail': ['aditya.adinasa@gmail.com', 'aditya.adinasa@gmail.com'], 'Qualification': [['CBSE', '1995']], 'Skills': ['Matplotlib', 'Jupyter', 'data analysis', 'consulting', 'analysis', 'analytics', 'Data Analysis', 'SQL', 'Data Analytics', 'research', 'DB2', 'Tableau', 'Banking', 'analyze', 'workflows', 'machine learning', 'Process', 'gmail', 'Seaborn', 'Hive', 'Engineering', 'Design', 'R', 'Big Data', 'Analysis', 'Electronics', 'algorithms', 'Machine learning', 'try', 'MySQL', 'banking', 'Machine Learning', 'Python', 'general ledger', 'Modeling', 'transactions', 'ETL', 'presentations', 'TECHNICAL', 'certification', 'business intelligence', 'Pandas', 'Communication', 'Automation', 'marketing', 'Architecture', 'TECHNICAL SKILLS', 'hypothesis', 'Numpy']}, {'ID': '128', 'Name': 'AKASHNIL', 'Phone Number': ['8092044772', '0192020', '9774621'], 'E-Mail': ['akashnil64@gmail.com', 'akashnil64@gmail.com'],
# ...

# %% [markdown]
# {'ID': '114', 'Name': 'SUMMARY', 'Qualification': [['MS', '2000']], 'Skills': ['test plans', 'IBM', 'Software Development Life Cycle', 'plan', 'SOAP', 'Excel', 'Sales', 'DB2', 'Cloud', 'MS Project', 'Soap', 'Oracle', 'Fulfillment', 'strategy', 'UNIX', 'transactions', 'JIRA', 'Scrum', 'writing', 'JAVA', 'Mobile', 'Test plans', 'HTML', 'analytical', 'Servers', 'Test cases', 'communication', 'data quality', 'Plan', 'debugging', 'life cycle', 'queries', 'Python', 'Access', 'XML', 'Agile', 'CSS', 'Java', 'Operating Systems', 'test cases', 'database', 'analysis', 'reports', 'SDLC', 'process', 'email', 'Test Plans', 'UI', 'Windows', 'programming', 'test case', 'Visio', 'automation', 'VB Script', 'SharePoint', 'SCRUM', 'JAD', 'Selenium', 'Testing', 'Database', 'test Case', 'Automation', 'TECHNICAL SKILLS', 'Test Cases', 'Business analysis', 'JavaScript', 'SQL', 'access', 'System', 'Warehouse', 'architecture', 'documentation', 'User stories', 'reporting', 'GitHub', 'testing', 'LINUX', 'banking', 'Queries', 'Reports', 'Troubleshooting', 'ETL']}

# %%
import bcrypt
import json
users = {'admin': {'password': 'PalmTree'},
         'user2': {'password': 'password2'}}

# Hash the passwords and update the 'users' dictionary
for username, user_data in users.items():
    password = user_data['password']
    hashed_password = bcrypt.hashpw(password.encode('utf-8'), bcrypt.gensalt())
    user_data['password'] = hashed_password.decode('utf-8')

# Store the updated 'users' dictionary in a file
with open('static/users', 'w') as file:
    json.dump(users, file)
